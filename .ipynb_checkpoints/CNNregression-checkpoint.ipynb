# %%
import keras
import csv
import scipy
import numpy as np
import nltk #from nltk.tokenize import punkt #.tokenize.moses import MosesTokenizer
from gensim.models import KeyedVectors
from itertools import islice
import pickle
import pandas as pd
import re
from nltk.corpus import stopwords
import json
import pickle
from cyordereddict import OrderedDict
from joblib import Parallel, delayed
pattern = re.compile(r'[^\s\w_]+')

DATASET_FILE_PATH = "./DataSet/yelp.csv/yelp.csv"
WORD2VEC_FILE_PATH = "./DataSet/FBword2vec/wiki.en.vec"
TRAINING_DATA_PATH = "./DataSet/trainingData"
EXTENDED_DATASET_PATH = "./DataSet/review.json"

###File Names
TEST_NAME = "standard_tokenizer_withStopwords_noPunctuation_FB_vectors_100percentDataset"

EMBEDDED_MATRIX_NAME = TEST_NAME+'_embedded_matrix.pkl'
TOKENIZED_SENTENCES_NAME = TEST_NAME+ "_tokenized_sentences.pkl"
WORD_INDEX_NAME = TEST_NAME+ "_word_index.pkl"
INDEXED_TOKENIZED_SENTENCES_NAME = TEST_NAME + "_indexed_tokenized_sentences.pkl"

LABELS_NAME = 'labels.pkl'


AMOUNT_OF_WORDS = 70
FACEBOOK_EMBEDDING_SIZE = 300
# Out:
# C:\Users\skymont\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
word_index = pickle.load(open(WORD_INDEX_NAME,'rb'))

# %%
embedded_matrix =  np.load(EMBEDDED_MATRIX_NAME+'.npy')
print('embedded matrix loaded')
# Out:
# embedded matrix loaded

# %%
indexed_tokenized_sentences = pickle.load(open(INDEXED_TOKENIZED_SENTENCES_NAME,'rb'))

# %%
def reshapeSentences(indexed_tokenized_sentences,sentence_length):
    for i in range(len(indexed_tokenized_sentences)):
        padding = sentence_length - len(indexed_tokenized_sentences[i])
        indexed_tokenized_sentences[i] = indexed_tokenized_sentences[i][:sentence_length] + [-1]*padding
    return indexed_tokenized_sentences

# %%
### BUILDING MODEL

# %%
reshaped_Sentences = reshapeSentences(indexed_tokenized_sentences, AMOUNT_OF_WORDS)

# %%
labels = pd.read_pickle("labels.pkl")

# %%
from keras.layers import Embedding
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.layers import SpatialDropout1D
from keras.layers import Dropout
from sklearn.model_selection import train_test_split
import numpy as np
from keras import backend
# fix random seed for reproducibility
seed = 42
np.random.seed(seed)

# %%
embedding_layer = Embedding(
    len(word_index),
    FACEBOOK_EMBEDDING_SIZE,
    weights=[embedded_matrix],
    input_length=AMOUNT_OF_WORDS,
    trainable=True
)

# %%
reshaped_Sentences = np.stack(reshaped_Sentences,axis=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(reshaped_Sentences, labels.values, test_size=0.2, random_state=42)

# %%
def generator(features, labels, batch_size, replace=True):
    
    batch_features = np.zeros((batch_size,AMOUNT_OF_WORDS))
    batch_labels = np.zeros((batch_size,4))
    while True:
        index = np.random.choice(features.shape[0], batch_size, replace=replace)
        batch_features[:] = features[index]
        batch_labels[:] = labels[index]
        yield batch_features, batch_labels

# %%
def precisionMetric(y_true,y_pred):
    #return tf.metrics.mean(y_true - tf.round(y_pred))[0]
    return backend.mean(y_true - backend.round(y_pred))

# %%
def percentageCorrect(y_true, y_pred):
    return backend.mean(backend.equal(y_true, backend.round(y_pred)))*100

# %%
model = Sequential()
model.add(embedding_layer)
model.add(Conv1D(filters=32, kernel_size=10, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
SpatialDropout1D(0.5)
model.add(Conv1D(filters=16, kernel_size=10, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=8, kernel_size=10, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
SpatialDropout1D(0.5)
model.add(Conv1D(filters=8, kernel_size=10, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
SpatialDropout1D(0.5)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.8))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.8))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.8))
model.add(Dense(128, activation='relu'))
model.add(Dense(4))
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=[percentageCorrect])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 70, 300)           57183900
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 70, 32)            96032
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 35, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 35, 16)            5136
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 17, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 17, 8)             1288
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 8, 8)              0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 8, 8)              648
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 4, 8)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 57,731,296
# Trainable params: 57,731,296
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.fit(X_train,y_train,validation_data=(X_test, y_test), epochs=40, batch_size=10, verbose=2)
model.fit_generator(generator(X_train,y_train,10000,False),steps_per_epoch=40, epochs=200, verbose=2, validation_data=generator(X_test, y_test, 5000, True), validation_steps=5)
# Out:
# Epoch 1/200
#  - 22s - loss: 1.2211 - percentageCorrect: 50.7003 - val_loss: 1.0171 - val_percentageCorrect: 54.4950
# Epoch 2/200
#  - 11s - loss: 0.9339 - percentageCorrect: 57.0064 - val_loss: 0.8687 - val_percentageCorrect: 56.2970
# Epoch 3/200
#  - 11s - loss: 0.8686 - percentageCorrect: 58.3596 - val_loss: 0.8045 - val_percentageCorrect: 59.4790
# Epoch 4/200
#  - 11s - loss: 0.8448 - percentageCorrect: 58.5798 - val_loss: 0.7979 - val_percentageCorrect: 59.0050
# Epoch 5/200
#  - 11s - loss: 0.8251 - percentageCorrect: 59.3473 - val_loss: 0.7706 - val_percentageCorrect: 61.6060
# Epoch 6/200
#  - 11s - loss: 0.8154 - percentageCorrect: 59.7990 - val_loss: 0.7970 - val_percentageCorrect: 60.4930
# Epoch 7/200
#  - 11s - loss: 0.8104 - percentageCorrect: 59.8121 - val_loss: 0.7721 - val_percentageCorrect: 61.1530
# Epoch 8/200
#  - 11s - loss: 0.8035 - percentageCorrect: 60.1167 - val_loss: 0.7608 - val_percentageCorrect: 61.3910
# Epoch 9/200
#  - 11s - loss: 0.7954 - percentageCorrect: 60.5732 - val_loss: 0.7795 - val_percentageCorrect: 61.3800
# Epoch 10/200
#  - 11s - loss: 0.7923 - percentageCorrect: 60.7351 - val_loss: 0.7641 - val_percentageCorrect: 61.3570
# Epoch 11/200
#  - 11s - loss: 0.7888 - percentageCorrect: 60.9122 - val_loss: 0.7710 - val_percentageCorrect: 60.6530
# Epoch 12/200
#  - 11s - loss: 0.7882 - percentageCorrect: 61.0208 - val_loss: 0.7639 - val_percentageCorrect: 60.7180
# Epoch 13/200
#  - 11s - loss: 0.7781 - percentageCorrect: 61.3376 - val_loss: 0.7492 - val_percentageCorrect: 61.3730
# Epoch 14/200
#  - 11s - loss: 0.7748 - percentageCorrect: 61.4652 - val_loss: 0.7813 - val_percentageCorrect: 60.3470
# Epoch 15/200
#  - 11s - loss: 0.7718 - percentageCorrect: 61.5034 - val_loss: 0.7499 - val_percentageCorrect: 62.6630
# Epoch 16/200
#  - 11s - loss: 0.7710 - percentageCorrect: 61.6111 - val_loss: 0.7510 - val_percentageCorrect: 62.6960
# Epoch 17/200
#  - 11s - loss: 0.7643 - percentageCorrect: 61.8777 - val_loss: 0.7705 - val_percentageCorrect: 63.0820
# Epoch 18/200
#  - 11s - loss: 0.7641 - percentageCorrect: 62.0407 - val_loss: 0.7382 - val_percentageCorrect: 63.6780
# Epoch 19/200
#  - 11s - loss: 0.7619 - percentageCorrect: 62.2916 - val_loss: 0.7686 - val_percentageCorrect: 63.1770
# Epoch 20/200
#  - 11s - loss: 0.6789 - percentageCorrect: 65.7646 - val_loss: 0.7147 - val_percentageCorrect: 64.0350
# Epoch 115/200
#  - 11s - loss: 0.6808 - percentageCorrect: 65.6981 - val_loss: 0.7369 - val_percentageCorrect: 63.6030
# Epoch 116/200
#  - 11s - loss: 0.6802 - percentageCorrect: 65.6859 - val_loss: 0.6903 - val_percentageCorrect: 65.3740
# Epoch 117/200
#  - 11s - loss: 0.6830 - percentageCorrect: 65.7270 - val_loss: 0.6979 - val_percentageCorrect: 65.0160
# Epoch 118/200
#  - 11s - loss: 0.6803 - percentageCorrect: 65.7483 - val_loss: 0.6980 - val_percentageCorrect: 64.9050
# Epoch 119/200
#  - 11s - loss: 0.6747 - percentageCorrect: 65.7085 - val_loss: 0.6771 - val_percentageCorrect: 64.8270
# Epoch 120/200
#  - 11s - loss: 0.6767 - percentageCorrect: 65.7940 - val_loss: 0.7088 - val_percentageCorrect: 64.7570
# Epoch 121/200
#  - 11s - loss: 0.6750 - percentageCorrect: 65.8696 - val_loss: 0.6912 - val_percentageCorrect: 65.2820
# Epoch 122/200
#  - 11s - loss: 0.6742 - percentageCorrect: 65.7869 - val_loss: 0.6994 - val_percentageCorrect: 64.9790
# Epoch 123/200
#  - 11s - loss: 0.6723 - percentageCorrect: 65.8117 - val_loss: 0.7141 - val_percentageCorrect: 64.8660
# Epoch 124/200
#  - 11s - loss: 0.6771 - percentageCorrect: 65.8196 - val_loss: 0.6998 - val_percentageCorrect: 65.0190
# Epoch 125/200
#  - 11s - loss: 0.6709 - percentageCorrect: 65.8498 - val_loss: 0.7107 - val_percentageCorrect: 64.7830
# Epoch 126/200
#  - 11s - loss: 0.6773 - percentageCorrect: 65.7841 - val_loss: 0.7170 - val_percentageCorrect: 63.9130
# Epoch 127/200
#  - 11s - loss: 0.6743 - percentageCorrect: 65.9071 - val_loss: 0.6949 - val_percentageCorrect: 65.3530
# Epoch 128/200
#  - 11s - loss: 0.6737 - percentageCorrect: 65.8210 - val_loss: 0.6891 - val_percentageCorrect: 65.0040
# Epoch 129/200
#  - 11s - loss: 0.6699 - percentageCorrect: 65.8177 - val_loss: 0.7105 - val_percentageCorrect: 64.2900
# Epoch 130/200
#  - 11s - loss: 0.6698 - percentageCorrect: 65.9182 - val_loss: 0.6853 - val_percentageCorrect: 64.7510
# Epoch 131/200
#  - 11s - loss: 0.6728 - percentageCorrect: 65.8773 - val_loss: 0.6871 - val_percentageCorrect: 64.9850
# Epoch 132/200
#  - 11s - loss: 0.6759 - percentageCorrect: 65.9225 - val_loss: 0.6803 - val_percentageCorrect: 65.4620
# Epoch 133/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-03f322dc90c6> in <module>()
#       1 #model.fit(X_train,y_train,validation_data=(X_test, y_test), epochs=40, batch_size=10, verbose=2)
# ----> 2 model.fit_generator(generator(X_train,y_train,10000,False),steps_per_epoch=40, epochs=200, verbose=2, validation_data=generator(X_test, y_test, 5000, True), validation_steps=5)
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424             use_multiprocessing=use_multiprocessing,
#    1425             shuffle=shuffle,
# -> 1426             initial_epoch=initial_epoch)
#    1427
#    1428     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     189                 outs = model.train_on_batch(x, y,
#     190                                             sample_weight=sample_weight,
# --> 191                                             class_weight=class_weight)
#     192
#     193                 if not isinstance(outs, list):
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1218             ins = x + y + sample_weights
#    1219         self._make_train_function()
# -> 1220         outputs = self.train_function(ins)
#    1221         if len(outputs) == 1:
#    1222             return outputs[0]
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
y_train
